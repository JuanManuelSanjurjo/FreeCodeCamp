# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.5.3

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame(data=[None], index=[None], columns=[None])
# Out:
#       None
# None  None

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
# your code goes here
marvel_df = pd.DataFrame(data=marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
# your code goes here
names = ["name","sex","first_appearance"]
marvel_df.columns = names
marvel_df
# Out:
#                 name     sex  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# 19            Vision    male              1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
# your code goes here
marvel_df.index = marvel_df["name"]
marvel_df
# Out:
#                               name     sex  first-appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %%
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first-appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df = marvel_df.drop(columns=["name"])
marvel_df
# Out:
#                      sex  first-appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
# your code goes here
marvel_df.drop(["Namor","Hank Pym"], axis=0)
# Out:
#                      sex  first-appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df.head(5)
marvel_df.iloc[:5]
# Out:
#                   sex  first-appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                   sex  first-appearance
# name
# Spider-Man       male              1962
# Captain America  male              1941
# Wolverine        male              1974
# Iron Man         male              1963
# Thor             male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df.iloc[-5:]
marvel_df.tail()
# Out:
#                   sex  first-appearance
# name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
# marvel_df.iloc[:5,:1]
marvel_df.iloc[:5,].sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   sex
# name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
# marvel_df.iloc[1:-1,-1:]
marvel_df.iloc[1:-1].first_appearance.to_frame()
# Out:
#     first_appearance
# 1               1941
# 2               1974
# 3               1963
# 4               1963
# 5               1961
# 6               1961
# 7               1962
# 8               1963
# 9               1961
# 10              1975
# 11              1939
# 12              1964
# 13              1964
# 14              1963
# 15              1962
# 16              1964
# 17              1963
# 18              1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()
# Out:
#     first_appearance
# 1               1941
# 2               1974
# 3               1963
# 4               1963
# 5               1961
# 6               1961
# 7               1962
# 8               1963
# 9               1961
# 10              1975
# 11              1939
# 12              1964
# 13              1964
# 14              1963
# 15              1962
# 16              1964
# 17              1963
# 18              1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[0,-1]]
# Out:
#           name   sex  first_appearance
# 0   Spider-Man  male              1962
# 19      Vision  male              1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]
# Out:
#           name   sex  first_appearance
# 0   Spider-Man  male              1962
# 19      Vision  male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df.loc["Vision","first_appearance"] = 1964

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df
# Out:
#                     name     sex  first_appearance
# 0             Spider-Man    male            1962.0
# 1        Captain America    male            1941.0
# 2              Wolverine    male            1974.0
# 3               Iron Man    male            1963.0
# 4                   Thor    male            1963.0
# 5                  Thing    male            1961.0
# 6       Mister Fantastic    male            1961.0
# 7                   Hulk    male            1962.0
# 8                  Beast    male            1963.0
# 9        Invisible Woman  female            1961.0
# 10                 Storm  female            1975.0
# 11                 Namor    male            1939.0
# 12               Hawkeye    male            1964.0
# 13             Daredevil    male            1964.0
# 14        Doctor Strange    male            1963.0
# 15              Hank Pym    male            1962.0
# 16         Scarlet Witch  female            1964.0
# 17                  Wasp  female            1963.0
# 18           Black Widow  female            1964.0
# 19                Vision    male            1968.0
# Vision               NaN     NaN            1964.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df["years_since"] = 2023 - marvel_df["first_appearance"]

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df
# Out:
#                     name     sex  first_appearance  years_since
# 0             Spider-Man    male            1962.0         56.0
# 1        Captain America    male            1941.0         77.0
# 2              Wolverine    male            1974.0         44.0
# 3               Iron Man    male            1963.0         55.0
# 4                   Thor    male            1963.0         55.0
# 5                  Thing    male            1961.0         57.0
# 6       Mister Fantastic    male            1961.0         57.0
# 7                   Hulk    male            1962.0         56.0
# 8                  Beast    male            1963.0         55.0
# 9        Invisible Woman  female            1961.0         57.0
# 10                 Storm  female            1975.0         43.0
# 11                 Namor    male            1939.0         79.0
# 12               Hawkeye    male            1964.0         54.0
# 13             Daredevil    male            1964.0         54.0
# 14        Doctor Strange    male            1963.0         55.0
# 15              Hank Pym    male            1962.0         56.0
# 16         Scarlet Witch  female            1964.0         54.0
# 17                  Wasp  female            1963.0         55.0
# 18           Black Widow  female            1964.0         54.0
# 19                Vision    male            1968.0         50.0
# Vision               NaN     NaN            1964.0         54.0

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask = marvel_df["sex"] == "female"
mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True
# 10         True
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17         True
# 18         True
# 19        False
# Vision    False
# Name: sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask = marvel_df['sex'] == 'male'

marvel_df[mask]
# Out:
#                 name   sex  first_appearance  years_since
# 0         Spider-Man  male            1962.0         56.0
# 1    Captain America  male            1941.0         77.0
# 2          Wolverine  male            1974.0         44.0
# 3           Iron Man  male            1963.0         55.0
# 4               Thor  male            1963.0         55.0
# 5              Thing  male            1961.0         57.0
# 6   Mister Fantastic  male            1961.0         57.0
# 7               Hulk  male            1962.0         56.0
# 8              Beast  male            1963.0         55.0
# 11             Namor  male            1939.0         79.0
# 12           Hawkeye  male            1964.0         54.0
# 13         Daredevil  male            1964.0         54.0
# 14    Doctor Strange  male            1963.0         55.0
# 15          Hank Pym  male            1962.0         56.0
# 19            Vision  male            1968.0         50.0

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
mask = marvel_df["first_appearance"] > 1970

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
#          name     sex  first_appearance  years_since
# 2   Wolverine    male            1974.0         44.0
# 10      Storm  female            1975.0         43.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
mask = (marvel_df["first_appearance"] > 1970) & (marvel_df["sex"] == "female")
marvel_df[mask]
# Out:
#      name     sex  first_appearance  years_since
# 10  Storm  female            1975.0         43.0

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]
# Out:
#      name     sex  first_appearance  years_since
# 10  Storm  female            1975.0         43.0

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.describe()
# marvel_df["first_appearance"].median()
# Out:
#        first_appearance  years_since
# count         21.000000    21.000000
# mean        1961.952381    56.047619
# std            8.206560     8.206560
# min         1939.000000    43.000000
# 25%         1962.000000    54.000000
# 50%         1963.000000    55.000000
# 75%         1964.000000    56.000000
# max         1975.000000    79.000000

# %%
marvel_df.describe()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df["first_appearance"].mean()
# Out:
# 1961.952380952381

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()
# Out:
# 1961.952380952381

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.min()
# Out:
# 1939.0

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
mask = marvel_df.first_appearance == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#      name   sex  first_appearance  years_since
# 11  Namor  male            1939.0         79.0

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#      name   sex  first_appearance  years_since
# 11  Namor  male            1939.0         79.0

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df = marvel_df.reset_index()

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#      index              name     sex  first_appearance  years_since
# 0        0        Spider-Man    male            1962.0         56.0
# 1        1   Captain America    male            1941.0         77.0
# 2        2         Wolverine    male            1974.0         44.0
# 3        3          Iron Man    male            1963.0         55.0
# 4        4              Thor    male            1963.0         55.0
# 5        5             Thing    male            1961.0         57.0
# 6        6  Mister Fantastic    male            1961.0         57.0
# 7        7              Hulk    male            1962.0         56.0
# 8        8             Beast    male            1963.0         55.0
# 9        9   Invisible Woman  female            1961.0         57.0
# 10      10             Storm  female            1975.0         43.0
# 11      11             Namor    male            1939.0         79.0
# 12      12           Hawkeye    male            1964.0         54.0
# 13      13         Daredevil    male            1964.0         54.0
# 14      14    Doctor Strange    male            1963.0         55.0
# 15      15          Hank Pym    male            1962.0         56.0
# 16      16     Scarlet Witch  female            1964.0         54.0
# 17      17              Wasp  female            1963.0         55.0
# 18      18       Black Widow  female            1964.0         54.0
# 19      19            Vision    male            1968.0         50.0
# 20  Vision               NaN     NaN            1964.0         54.0

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df["first_appearance"].plot()
# Out:
# <Axes: >

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
# your code goes here
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 16.,  0.,  1.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(marvel_df.first_appearance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
